# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cross_validation import train_test_split
from sklearn.metrics import classification_report 
from sklearn.decomposition import NMF, LatentDirichletAllocation
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
clinton = pd.read_csv('/Users/michaelulin/Project Q2 Gu/output/Emails.csv')

# %%
clinton.columns
# Out:
# Index([u'Id', u'DocNumber', u'MetadataSubject', u'MetadataTo', u'MetadataFrom',
#        u'SenderPersonId', u'MetadataDateSent', u'MetadataDateReleased',
#        u'MetadataPdfLink', u'MetadataCaseNumber', u'MetadataDocumentClass',
#        u'ExtractedSubject', u'ExtractedTo', u'ExtractedFrom', u'ExtractedCc',
#        u'ExtractedDateSent', u'ExtractedCaseNumber', u'ExtractedDocNumber',
#        u'ExtractedDateReleased', u'ExtractedReleaseInPartOrFull',
#        u'ExtractedBodyText', u'RawText'],
#       dtype='object')

# %%
features = clinton['ExtractedBodyText']

# %%
features = features.dropna()

# %%
vect = CountVectorizer(stop_words="english", max_features = 5000)

# %%
x_features = vect.fit_transform(features)

# %%
nmf = NMF(n_components=10)

# %%
x_features
# Out:
# <6742x5000 sparse matrix of type '<type 'numpy.int64'>'
# 	with 169891 stored elements in Compressed Sparse Row format>

# %%
W = nmf.fit_transform(x_features)

# %%
H = nmf.components_

# %%
vector_features = vect.get_feature_names()

# %%
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print "Topic #%d:" % topic_idx
        print " ".join([feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]])
          
print_top_words(nmf, vector_features, 50)
# Out:
# Topic #0:
# state 2015 benghazi department information subject 13 agreement house case sensitive doc date 05 produced dept comm waiver foia redactions 04841 select people c05739812 libya united states violence world today indonesia morocco chris government security thank attack work foreign minister let working colleagues libyan protect continue want c05739767 secretary 2012
# Topic #1:
# koch kochs charles david said company million political dollars obama party tea americans group prosperity industries told public brothers president center government think movement family cancer new people money corporate institute years environmental oil national called board formaldehyde tax spent time report conservative cato mercatus libertarian year foundation known climate
# Topic #2:
# ...

# %%
feat = np.array(features)

# %%
for topic in range(W.shape[1]):
    #max_t = np.argmax(W[:,topic])
    print "TOPIC: ",topic
    #print features[max_t][0:150]
    
    for t in range(6):
        n = int(-1-t)
        max_2t = W[:,topic].argsort()[n]
        try:
            print t," : _____________" 
            print feat[max_2t][0:500]
        except:
            continue
# Out:
# TOPIC:  0
# 0  : _____________
# Attached is full compilation. You never said spontaneous or characterized the motives. in fact you were careful in your
# first statement to say we were assessing motive and method. The way you treated the video in the Libya context was to
# say that some sought to *justify* the attack on that basis.
# From Valliani, Amira
# Sent: Monday, September 24, 2012 10:08 AM
# To: Sullivan, Jacob 3
# Subject: Berthazi/protest statements
# Attached
# U.S. Department of State
# Case No. F-2015-04841
# Doc No. C05739812
# Date:
# 1  : _____________
# B5
# Megan is working on a development speech but please read the below if you can this afternoon.
# Let me know your thoughts.
# U.S. Department of State
# Case No. F-2015-04841
# Doc No. C05739767
# Date: 05/13/2015
# STATE DEPT. - PRODUCED TO HOUSE SELECT BENGHAZI COMM.
# SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION & REDACTIONS. NO FOIA WAIVER. STATE-5CB0045428
# U.S. Department of State
# Case No. F-2015-04841
# ...
